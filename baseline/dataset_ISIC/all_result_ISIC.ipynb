# %%
#

"""
baseline Medsam

baseline no_adapter no_ubloss
Evaluated on: val.txt
Processed 519 images.
Mean Dice: 0.8608  (Std: 0.1004)
Mean IoU : 0.7667  (Std: 0.1286)

busi_run19 adapter 0.015_ubloss 
--- Evaluation Summary on Test Set (val.txt) ---
==================================================
    category  mean_dice  std_dice  mean_iou   std_iou  count
0  malignant   0.913225  0.060633  0.845005  0.086281    519
==================================================

ISIC_run1 adapter no_ubloss   1024
==================================================
--- Evaluation Summary on Test Set (val.txt) ---
==================================================
    category  mean_dice  std_dice  mean_iou   std_iou  count
0  malignant   0.944183  0.053448  0.898092  0.077458    519
==================================================

ISIC_run2 adapter no_ubloss   512
--- Evaluation Summary on Test Set (val.txt) ---
==================================================
    category  mean_dice  std_dice  mean_iou   std_iou  count
0  malignant   0.927865  0.063275  0.870799  0.092944    519
==================================================

ISIC_run3 adapter 0.015_ubloss   1024
--- Evaluation Summary on Test Set (val.txt) ---
==================================================
    category  mean_dice  std_dice  mean_iou   std_iou  count
0  malignant   0.944359  0.055513  0.898657  0.079405    519
==================================================

ISIC_run4 adapter 0.3_ubloss   1024
--- Evaluation Summary on Test Set (val.txt) ---
==================================================
    category  mean_dice  std_dice  mean_iou   std_iou  count
0  malignant   0.927795  0.061455  0.870335  0.089136    519
==================================================

ISIC_run5 adapter 0.01_ubloss   1024
--- Evaluation Summary on Test Set (val.txt) ---
==================================================
    category  mean_dice  std_dice  mean_iou   std_iou  count
0  malignant   0.943804  0.056524  0.897819  0.080958    519
==================================================

ISIC_run6 adapter 0.01_ubloss   512
              Mean    Std
dice        0.9283 0.0725
iou         0.8726 0.0974
accuracy    0.9682 0.0612
sensitivity 0.9016 0.0971
specificity 0.9893 0.0413


mesam2 baseline
--- MedSAM2 Evaluation Summary on Test Set (val.txt) ---
============================================================
    category  mean_dice  std_dice  mean_iou   std_iou  count
0  malignant   0.941649  0.041382  0.892298  0.066232    519
"""
