# %%
"""
sam2微调后
--- Overall Evaluation Summary ---
==============================
Processed 647 images.
Average Dice Score: 0.9276 ± 0.0365
Average IoU Score:  0.8670 ± 0.0606

sam2微调前
==============================
--- Per-Category Summary ---
==============================
    category  mean_dice  std_dice  mean_iou   std_iou  count
0     benign   0.905235  0.077924  0.834083  0.103092    437
1  malignant   0.859074  0.086002  0.761121  0.110356    210



sam2微调前 --only val.txt
==================================================
--- Evaluation Summary on Test Set (val.txt) ---
==================================================
    category  mean_dice  std_dice  mean_iou   std_iou  count
0     benign   0.910331  0.082025  0.842888  0.102311     91
1  malignant   0.873604  0.053202  0.779304  0.081171     39

==============================
sam2微调后 --fulltune Per-Category Summary ---  80m
==============================
    category  mean_dice  std_dice  mean_iou   std_iou  count
0     benign   0.939114  0.027782  0.886457  0.047555    437
1  malignant   0.903606  0.040739  0.826555  0.064831    210


sam2微调后  --adapter   --val.txt   1.4m
==================================================
    category  mean_dice  std_dice  mean_iou   std_iou  count
0     benign   0.939956  0.026413  0.887849  0.046049     91
1  malignant   0.907119  0.038260  0.832143  0.062178     39


==================================================
sam2微调后 --only val.txt  --只用边界损失权重10
--- Evaluation Summary on Test Set (val.txt) ---
==================================================
    category  mean_dice  std_dice  mean_iou   std_iou  count
0     benign   0.808405  0.056771  0.682106  0.078294     91
1  malignant   0.786501  0.056879  0.651684  0.077988     39
==================================================


MedSam2 --baseline
--- Overall Evaluation Summary ---
==============================
Processed 647 images.
Average Dice Score: 0.9294 ± 0.0360
Average IoU Score:  0.8702 ± 0.0597

==============================
--- Per-Category Summary ---
==============================
    category  mean_dice  std_dice  mean_iou   std_iou  count
0     benign   0.941491  0.026044  0.890541  0.044558    437
1  malignant   0.904393  0.040633  0.827862  0.064828    210
"""

# %% [markdown]
# sam2  --基于完整的busi
# medsam2 --基于完整的busi
#
#
#
#
#
#
# sam2微调后  --adapter   --val.txt   参数 1.8m
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.939956  0.026413  0.887849  0.046049     91
# 1  malignant   0.907119  0.038260  0.832143  0.062178     39
#
#
# bloss参数实验
#
# weight_dict:
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 5
#
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.828331  0.059934  0.711270  0.085200     91
# 1  malignant   0.824748  0.056889  0.705596  0.081442     39
# ==================================================
# run4
# weight_dict:
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 1
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.873547  0.049341  0.778767  0.075845     91
# 1  malignant   0.877651  0.050470  0.785360  0.077394     39
#
#
# run5
# weight_dict:
#   loss_mask: 10
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 1
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.868908  0.048584  0.771343  0.074013     91
# 1  malignant   0.858173  0.055831  0.755467  0.081864     39
# ==================================================
#
# run6
# weight_dict:
#   loss_mask: 10
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 5
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.820524  0.060774  0.699987  0.084886     91
# 1  malignant   0.805289  0.056701  0.677725  0.079764     39
# ==================================================
#
# run7
# weight_dict:
#   loss_mask: 10
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.5
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.878371  0.044680  0.785850  0.069325     91
# 1  malignant   0.879630  0.048638  0.788289  0.074921     39
# ==================================================
#
# run8
# weight_dict:
#   loss_mask: 10
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.1
#
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.924821  0.033206  0.861864  0.055960     91
# 1  malignant   0.906580  0.040042  0.831432  0.064789     39
# ==================================================
#
# run9
# weight_dict:
#   loss_mask: 10
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.2
#
# INFO 2025-09-21 18:59:19,793 trainer.py: 832: Losses and meters: {'
# Losses/train_all_loss': 2.975019139156007, 'Losses/train_all_loss_mask': 0.06902701747522019, 'Losses/train_all_loss_dice': 0.9919597255556207, 'Losses/train_all_loss_iou': 0.2900531584756416, 'Losses/train_all_loss_class': 8.96572455994144e-07, 'Losses/train_all_loss_ubl': 5.013675810997946, 'Losses/train_all_core_loss': 2.975019139156007, 'Trainer/where': 0.9996491228070176, 'Trainer/epoch': 49, 'Trainer/steps_train': 2850}
#
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.904130  0.038595  0.827220  0.062821     91
# 1  malignant   0.902435  0.044016  0.824978  0.070763     39
# ==================================================
#
# run10
# weight_dict:
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.2
# {'Losses/train_all_loss': 3.5049424192361665, 'Losses/train_all_loss_mask': 0.047923441812918896, 'Losses/train_all_loss_dice': 0.9934504084419786, 'Losses/train_all_loss_iou': 0.27859246417095784, 'Losses/train_all_loss_class': 2.2722129388824578e-07, 'Losses/train_all_loss_ubl': 6.372152499985277, 'Losses/train_all_core_loss': 3.5049424192361665, 'Trainer/where': 0.9996491228070176, 'Trainer/epoch': 49, 'Trainer/steps_train': 2850}
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.914125  0.037711  0.843978  0.062501     91
# 1  malignant   0.897391  0.044001  0.816638  0.071017     39
# ==================================================
#
# run11
# weight_dict:
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.5
# {'Losses/train_all_loss': 5.195168633210032, 'Losses/train_all_loss_mask': 0.0785461331537941, 'Losses/train_all_loss_dice': 1.1658434345011126, 'Losses/train_all_loss_iou': 0.3241530566623336, 'Losses/train_all_loss_class': 1.371503642156743e-06, 'Losses/train_all_loss_ubl': 4.268496291679249, 'Losses/train_all_core_loss': 5.195168633210032, 'Trainer/where': 0.9996491228070176, 'Trainer/epoch': 49, 'Trainer/steps_train': 2850}
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.891187  0.042762  0.806323  0.068013     91
# 1  malignant   0.885274  0.049988  0.797560  0.077913     39
#
#
# run12
# weight_dict:
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.3
# {'Losses/train_all_loss': 4.1230770746866865, 'Losses/train_all_loss_mask': 0.058123373867649784, 'Losses/train_all_loss_dice': 1.0736797838880305, 'Losses/train_all_loss_iou': 0.29355283061924736, 'Losses/train_all_loss_class': 3.581145633239937e-07, 'Losses/train_all_loss_ubl': 5.311255222872684, 'Losses/train_all_core_loss': 4.1230770746866865, 'Trainer/where': 0.9996491228070176, 'Trainer/epoch': 49, 'Trainer/steps_train': 2850}
# ==================================================
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.904946  0.041622  0.828939  0.067765     91
# 1  malignant   0.890179  0.049567  0.805489  0.078203     39
#
#
# run13
# weight_dict:
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.15
# {'Losses/train_all_loss': 3.104714744969418, 'Losses/train_all_loss_mask': 0.04202152880137427, 'Losses/train_all_loss_dice': 0.9463382593372411, 'Losses/train_all_loss_iou': 0.26299636392739784, 'Losses/train_all_loss_class': 3.442614128166636e-07, 'Losses/train_all_loss_ubl': 7.032994462732683, 'Losses/train_all_core_loss': 3.104714744969418, 'Trainer/where': 0.9996491228070176, 'Trainer/epoch': 49, 'Trainer/steps_train': 2850}
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.923047  0.035247  0.859007  0.059236     91
# 1  malignant   0.905809  0.040943  0.830242  0.066123     39
#
# run14
# weight_dict:
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.1
# {'Losses/train_all_loss': 2.6989169601808514, 'Losses/train_all_loss_mask': 0.03833402206369659, 'Losses/train_all_loss_dice': 0.8787381136626528, 'Losses/train_all_loss_iou': 0.25286098216709335, 'Losses/train_all_loss_class': 2.722362441338961e-07, 'Losses/train_all_loss_ubl': 8.00637103800188, 'Losses/train_all_core_loss': 2.6989169601808514, 'Trainer/where': 0.9996491228070176, 'Trainer/epoch': 49, 'Trainer/steps_train': 2850}
# ==================================================
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.932363  0.031396  0.874855  0.053602     91
# 1  malignant   0.911082  0.036717  0.838662  0.060187     39
# ==================================================
#
# run15
# weight_dict:
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.05
# {'Losses/train_all_loss': 2.239847963316399, 'Losses/train_all_loss_mask': 0.0351775764046531, 'Losses/train_all_loss_dice': 0.8099165950950823, 'Losses/train_all_loss_iou': 0.23176087099209167, 'Losses/train_all_loss_class': 4.5657361030257466e-07, 'Losses/train_all_loss_ubl': 9.892370274192409, 'Losses/train_all_core_loss': 2.239847963316399, 'Trainer/where': 0.9996491228070176, 'Trainer/epoch': 49, 'Trainer/steps_train': 2850}
# ==================================================
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.939253  0.027881  0.886721  0.048407     91
# 1  malignant   0.913418  0.033255  0.842287  0.055441     39
#
#
# run16
# weight_dict:
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.01
# {'Losses/train_all_loss': 1.7612762085178442, 'Losses/train_all_loss_mask': 0.031847317163881506, 'Losses/train_all_loss_dice': 0.770237561380654, 'Losses/train_all_loss_iou': 0.22015709730616786, 'Losses/train_all_loss_class': 7.352290166840304e-07, 'Losses/train_all_loss_ubl': 13.393448444834927, 'Losses/train_all_core_loss': 1.7612762085178442, 'Trainer/where': 0.9996491228070176, 'Trainer/epoch': 49, 'Trainer/steps_train': 2850}
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.943163  0.024303  0.893411  0.042705     91
# 1  malignant   0.913323  0.030271  0.841839  0.050364     39
# ==================================================
#
# run17
# weight_dict:
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.03
# {'Losses/train_all_loss': 1.9698242200048346, 'Losses/train_all_loss_mask': 0.03195970017757071, 'Losses/train_all_loss_dice': 0.7780553567827794, 'Losses/train_all_loss_iou': 0.21391423752433375, 'Losses/train_all_loss_class': 5.614032001560548e-07, 'Losses/train_all_loss_ubl': 11.288669427235922, 'Losses/train_all_core_loss': 1.9698242200048346, 'Trainer/where': 0.9996491228070176, 'Trainer/epoch': 49, 'Trainer/steps_train': 2850}
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.942046  0.025324  0.891491  0.044348     91
# 1  malignant   0.913260  0.034252  0.842093  0.056244     39
# ==================================================
#
# run18
# weight_dict:
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.02
#  {'Losses/train_all_loss': 1.8282659743961536, 'Losses/train_all_loss_mask': 0.030516225942655614, 'Losses/train_all_loss_dice': 0.7627050536766387, 'Losses/train_all_loss_iou': 0.20891355762356206, 'Losses/train_all_loss_class': 8.229455116141603e-07, 'Losses/train_all_loss_ubl': 12.316102278859992, 'Losses/train_all_core_loss': 1.8282659743961536, 'Trainer/where': 0.9996491228070176, 'Trainer/epoch': 49, 'Trainer/steps_train': 2850}
#  --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.943295  0.024328  0.893652  0.042855     91
# 1  malignant   0.914583  0.030915  0.844025  0.051038     39
# ==================================================
#
# run19
# weight_dict:
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.015
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.943450  0.024155  0.893915  0.042556     91
# 1  malignant   0.914201  0.031479  0.843435  0.052157     39
#
#
# weight_dict:21  512
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.015
# ==================================================
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.932501  0.031235  0.875077  0.053222     91
# 1  malignant   0.903164  0.032672  0.825005  0.054384     39
# ==================================================
#
#
# BLoss v2 Bloss/10  run1
# weight_dict:21  1024
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 0.15
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.941870   0.02529  0.891174  0.044346     91
# 1  malignant   0.915068   0.03193  0.844937  0.052492     39
# ==================================================
#
# BLoss v2 Bloss/100  run2
# weight_dict:21  1024
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 1.5
# --- Evaluation Summary on Test Set (val.txt) ---
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.940580   0.02760  0.889054  0.047700     91
# 1  malignant   0.908086   0.03267  0.833208  0.053643     39
# ==================================================
#
# BLoss v2 Bloss/100  run3
# weight_dict:21  1024
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 2
# ==================================================
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.942210  0.025619  0.891808  0.044862     91
# 1  malignant   0.911605  0.034231  0.839301  0.056571     39
# ==================================================
#
# BLoss v2 Bloss/100  run4
# weight_dict:21  1024
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 3
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.940239  0.026637  0.888372  0.046418     91
# 1  malignant   0.914056  0.031462  0.843193  0.052396     39
# ==================================================
#
# BLoss v2 Bloss/100  run5
# weight_dict:21  1024
#   loss_mask: 20
#   loss_dice: 1
#   loss_iou: 1
#   loss_class: 1
#   loss_ubl: 2.5
# --- Evaluation Summary on Test Set (val.txt) ---
# ==================================================
#     category  mean_dice  std_dice  mean_iou   std_iou  count
# 0     benign   0.942127  0.025501   0.89165  0.044673     91
# 1  malignant   0.913523  0.035400   0.84266  0.058252     39
# ==================================================
